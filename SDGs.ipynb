# %% [markdown]
# <a href="https://colab.research.google.com/github/SavannahY/Global-A.I.-Data-Science/blob/master/SDGs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SDG

# %% [markdown]
# ##Load the data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import seaborn as sns
# %matplotlib inline
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
path = 'gdrive/My Drive/SDG_Data_File_Daily.csv'
df = pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1604138 entries, 0 to 1604137
# Data columns (total 96 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Unnamed: 0            1604138 non-null  int64
#  1   Timestamp             1604138 non-null  object
#  2   Ticker                1604138 non-null  object
#  3   ISIN                  1601559 non-null  object
#  4   Company_Name          1604138 non-null  object
#  5   GICS Sector           1604138 non-null  object
#  6   SDG_1                 387681 non-null   float64
#  7   SDG_2                 422694 non-null   float64
#  8   SDG_3                 805362 non-null   float64
#  9   SDG_4                 648846 non-null   float64
#  10  SDG_5                 229394 non-null   float64
#  11  SDG_6                 344897 non-null   float64
#  12  SDG_7                 503870 non-null   float64
#  13  SDG_8                 911957 non-null   float64
#  14  SDG_9                 685784 non-null   float64
#  15  SDG_10                720027 non-null   float64
#  16  SDG_11                896346 non-null   float64
#  17  SDG_12                516385 non-null   float64
#  18  SDG_13                365288 non-null   float64
#  19  SDG_14                318833 non-null   float64
#  20  SDG_15                393312 non-null   float64
#  21  SDG_16                821992 non-null   float64
#  22  SDG_17                352580 non-null   float64
#  23  SDG_Mean              1015324 non-null  float64
#  24  STS_1                 1266540 non-null  float64
#  25  STS_2                 1302011 non-null  float64
#  26  STS_3                 1445644 non-null  float64
#  27  STS_4                 1420867 non-null  float64
#  28  STS_5                 1058791 non-null  float64
#  29  STS_6                 1233136 non-null  float64
#  30  STS_7                 1336369 non-null  float64
#  31  STS_8                 1484403 non-null  float64
#  32  STS_9                 1430361 non-null  float64
#  33  STS_10                1451407 non-null  float64
#  34  STS_11                1481187 non-null  float64
#  35  STS_12                1352800 non-null  float64
#  36  STS_13                1241856 non-null  float64
#  37  STS_14                1215373 non-null  float64
#  38  STS_15                1255458 non-null  float64
#  39  STS_16                1471184 non-null  float64
#  40  STS_17                1220113 non-null  float64
#  41  STS_Mean              1501782 non-null  float64
#  42  LTS_1                 1150773 non-null  float64
#  43  LTS_2                 1191963 non-null  float64
#  44  LTS_3                 1382040 non-null  float64
#  45  LTS_4                 1339487 non-null  float64
#  46  LTS_5                 896946 non-null   float64
#  47  LTS_6                 1120889 non-null  float64
#  48  LTS_7                 1246525 non-null  float64
#  49  LTS_8                 1432520 non-null  float64
#  50  LTS_9                 1356203 non-null  float64
#  51  LTS_10                1382090 non-null  float64
#  52  LTS_11                1427490 non-null  float64
#  53  LTS_12                1260600 non-null  float64
#  54  LTS_13                1132251 non-null  float64
#  55  LTS_14                1087025 non-null  float64
#  56  LTS_15                1148964 non-null  float64
#  57  LTS_16                1407379 non-null  float64
#  58  LTS_17                1112797 non-null  float64
#  59  LTS_Mean              1449726 non-null  float64
#  60  SDG_1_STD             387681 non-null   float64
#  61  SDG_2_STD             422694 non-null   float64
#  62  SDG_3_STD             805362 non-null   float64
#  63  SDG_4_STD             648846 non-null   float64
#  64  SDG_5_STD             229394 non-null   float64
#  65  SDG_6_STD             344897 non-null   float64
#  66  SDG_7_STD             503870 non-null   float64
#  67  SDG_8_STD             911957 non-null   float64
#  68  SDG_9_STD             685784 non-null   float64
#  69  SDG_10_STD            720027 non-null   float64
#  70  SDG_11_STD            896346 non-null   float64
#  71  SDG_12_STD            516385 non-null   float64
#  72  SDG_13_STD            365288 non-null   float64
#  73  SDG_14_STD            318833 non-null   float64
#  74  SDG_15_STD            393312 non-null   float64
#  75  SDG_16_STD            821992 non-null   float64
#  76  SDG_17_STD            352580 non-null   float64
#  77  SDG_STD_Mean          1015324 non-null  float64
#  78  SDG_1_News_Volume     387681 non-null   float64
#  79  SDG_2_News_Volume     422694 non-null   float64
#  80  SDG_3_News_Volume     805362 non-null   float64
#  81  SDG_4_News_Volume     648846 non-null   float64
#  82  SDG_5_News_Volume     229394 non-null   float64
#  83  SDG_6_News_Volume     344897 non-null   float64
#  84  SDG_7_News_Volume     503870 non-null   float64
#  85  SDG_8_News_Volume     911957 non-null   float64
#  86  SDG_9_News_Volume     685784 non-null   float64
#  87  SDG_10_News_Volume    720027 non-null   float64
#  88  SDG_11_News_Volume    896346 non-null   float64
#  89  SDG_12_News_Volume    516385 non-null   float64
#  90  SDG_13_News_Volume    365288 non-null   float64
#  91  SDG_14_News_Volume    318833 non-null   float64
#  92  SDG_15_News_Volume    393312 non-null   float64
#  93  SDG_16_News_Volume    821992 non-null   float64
#  94  SDG_17_News_Volume    352580 non-null   float64
#  95  SDG_News_Volume_Mean  1015324 non-null  float64
# dtypes: float64(90), int64(1), object(5)
# memory usage: 1.1+ GB

# %%
df.head()
# Out:
#    Unnamed: 0   Timestamp  ... SDG_17_News_Volume SDG_News_Volume_Mean
# 0           0  2013-04-01  ...                NaN                  NaN
# 1           1  2013-04-02  ...                NaN                  NaN
# 2           2  2013-04-03  ...                NaN                  NaN
# 3           3  2013-04-04  ...                NaN                  NaN
# 4           4  2013-04-05  ...                NaN                  NaN
#
# [5 rows x 96 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0          SDG_1  ...  SDG_17_News_Volume  SDG_News_Volume_Mean
# count  1.604138e+06  387681.000000  ...       352580.000000          1.015324e+06
# mean   8.020685e+05      -0.357852  ...           12.311924          1.691596e+01
# std    4.630749e+05       2.102821  ...           50.670370          1.128878e+02
# min    0.000000e+00     -21.967213  ...            1.000000          1.000000e+00
# 25%    4.010342e+05      -1.555697  ...            1.000000          1.375000e+00
# 50%    8.020685e+05      -0.338983  ...            2.000000          2.666667e+00
# 75%    1.203103e+06       0.861347  ...            6.000000          6.500000e+00
# max    1.604137e+06      78.448919  ...         2377.000000          4.575176e+03
#
# [8 rows x 91 columns]

# %%
df.shape
# Out:
# (1604138, 96)

# %%
grouped_df = df.groupby(['GICS Sector','Ticker'])

# %%
grouped_df['SDG_News_Volume_Mean'].describe().unstack()
# Out:
#                          count          ...         max
# Ticker                       A     AAL  ...        ZION        ZTS
# GICS Sector                             ...
# Communication Services     NaN     NaN  ...         NaN        NaN
# Consumer Discretionary     NaN     NaN  ...         NaN        NaN
# Consumer Staples           NaN     NaN  ...         NaN        NaN
# Energy                     NaN     NaN  ...         NaN        NaN
# Financials                 NaN     NaN  ...  283.529412        NaN
# Health Care             2058.0     NaN  ...         NaN  32.142857
# Industrials                NaN  2572.0  ...         NaN        NaN
# Information Technology     NaN     NaN  ...         NaN        NaN
# Materials                  NaN     NaN  ...         NaN        NaN
# Real Estate                NaN     NaN  ...         NaN        NaN
# Utilities                  NaN     NaN  ...         NaN        NaN
#
# [11 rows x 4976 columns]

# %%
grouped_df['SDG_News_Volume_Mean'].mean().reset_index()
# Out:
#                 GICS Sector Ticker  SDG_News_Volume_Mean
# 0    Communication Services   ATVI              4.095152
# 1    Communication Services    CBS              1.816274
# 2    Communication Services   CHTR              4.840984
# 3    Communication Services  CMCSA             23.993411
# 4    Communication Services    CTL              2.594598
# ..                      ...    ...                   ...
# 617               Utilities     SO              9.102868
# 618               Utilities    SRE              3.472707
# 619               Utilities    UGI              1.464496
# 620               Utilities    WEC              1.271930
# 621               Utilities    XEL              6.089325
#
# [622 rows x 3 columns]

# %% [markdown]
# Measures of Variability in Python

# %% [markdown]
# Pandas Standard deviation

# %%
grouped_df['SDG_News_Volume_Mean'].std().reset_index()
# Out:
#                 GICS Sector Ticker  SDG_News_Volume_Mean
# 0    Communication Services   ATVI              3.813528
# 1    Communication Services    CBS              1.915781
# 2    Communication Services   CHTR              9.544643
# 3    Communication Services  CMCSA             29.892311
# 4    Communication Services    CTL              2.974711
# ..                      ...    ...                   ...
# 617               Utilities     SO             15.698301
# 618               Utilities    SRE              4.671249
# 619               Utilities    UGI              1.107565
# 620               Utilities    WEC              0.650793
# 621               Utilities    XEL              6.736067
#
# [622 rows x 3 columns]

# %% [markdown]
# Interquartile Range in Pandas

# %%
grouped_df['SDG_News_Volume_Mean'].quantile([.25, .5, .75]).unstack()
# Out:
#                                    0.25       0.50       0.75
# GICS Sector            Ticker
# Communication Services ATVI    2.000000   3.181818   4.923077
#                        CBS     1.000000   1.250000   2.000000
#                        CHTR    1.916667   3.111111   5.000000
#                        CMCSA   8.953125  16.705882  29.880515
#                        CTL     1.250000   2.000000   3.000000
# ...                                 ...        ...        ...
# Utilities              SO      3.384615   5.937500  10.081731
#                        SRE     1.333333   2.333333   4.000000
#                        UGI     1.000000   1.000000   1.555556
#                        WEC     1.000000   1.000000   1.237500
#                        XEL     2.857143   4.625000   7.266667
#
# [622 rows x 3 columns]

# %% [markdown]
# Pandas Variance

# %%
grouped_df['SDG_News_Volume_Mean'].var().reset_index()
# Out:
#                 GICS Sector Ticker  SDG_News_Volume_Mean
# 0    Communication Services   ATVI             14.542995
# 1    Communication Services    CBS              3.670216
# 2    Communication Services   CHTR             91.100217
# 3    Communication Services  CMCSA            893.550228
# 4    Communication Services    CTL              8.848904
# ..                      ...    ...                   ...
# 617               Utilities     SO            246.436666
# 618               Utilities    SRE             21.820570
# 619               Utilities    UGI              1.226701
# 620               Utilities    WEC              0.423531
# 621               Utilities    XEL             45.374592
#
# [622 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Timestamp', 'Ticker', 'ISIN', 'Company_Name',
#        'GICS Sector', 'SDG_1', 'SDG_2', 'SDG_3', 'SDG_4', 'SDG_5', 'SDG_6',
#        'SDG_7', 'SDG_8', 'SDG_9', 'SDG_10', 'SDG_11', 'SDG_12', 'SDG_13',
#        'SDG_14', 'SDG_15', 'SDG_16', 'SDG_17', 'SDG_Mean', 'STS_1', 'STS_2',
#        'STS_3', 'STS_4', 'STS_5', 'STS_6', 'STS_7', 'STS_8', 'STS_9', 'STS_10',
#        'STS_11', 'STS_12', 'STS_13', 'STS_14', 'STS_15', 'STS_16', 'STS_17',
#        'STS_Mean', 'LTS_1', 'LTS_2', 'LTS_3', 'LTS_4', 'LTS_5', 'LTS_6',
#        'LTS_7', 'LTS_8', 'LTS_9', 'LTS_10', 'LTS_11', 'LTS_12', 'LTS_13',
#        'LTS_14', 'LTS_15', 'LTS_16', 'LTS_17', 'LTS_Mean', 'SDG_1_STD',
#        'SDG_2_STD', 'SDG_3_STD', 'SDG_4_STD', 'SDG_5_STD', 'SDG_6_STD',
#        'SDG_7_STD', 'SDG_8_STD', 'SDG_9_STD', 'SDG_10_STD', 'SDG_11_STD',
#        'SDG_12_STD', 'SDG_13_STD', 'SDG_14_STD', 'SDG_15_STD', 'SDG_16_STD',
#        'SDG_17_STD', 'SDG_STD_Mean', 'SDG_1_News_Volume', 'SDG_2_News_Volume',
#        'SDG_3_News_Volume', 'SDG_4_News_Volume', 'SDG_5_News_Volume',
#        'SDG_6_News_Volume', 'SDG_7_News_Volume', 'SDG_8_News_Volume',
#        'SDG_9_News_Volume', 'SDG_10_News_Volume', 'SDG_11_News_Volume',
#        'SDG_12_News_Volume', 'SDG_13_News_Volume', 'SDG_14_News_Volume',
#        'SDG_15_News_Volume', 'SDG_16_News_Volume', 'SDG_17_News_Volume',
#        'SDG_News_Volume_Mean'],
#       dtype='object')

# %%
df.tail()
# Out:
#          Unnamed: 0   Timestamp  ... SDG_17_News_Volume SDG_News_Volume_Mean
# 1604133     1604133  2020-04-18  ...                NaN                  NaN
# 1604134     1604134  2020-04-19  ...                NaN                  NaN
# 1604135     1604135  2020-04-20  ...                NaN                  1.0
# 1604136     1604136  2020-04-21  ...                NaN                  1.0
# 1604137     1604137  2020-04-22  ...                NaN                  NaN
#
# [5 rows x 96 columns]

# %%
grouped_df.tail()
# Out:
#          Unnamed: 0   Timestamp  ... SDG_17_News_Volume SDG_News_Volume_Mean
# 2574           2574  2020-04-18  ...                NaN                  2.5
# 2575           2575  2020-04-19  ...                NaN                  NaN
# 2576           2576  2020-04-20  ...                NaN                  1.5
# 2577           2577  2020-04-21  ...                NaN                  3.2
# 2578           2578  2020-04-22  ...                NaN                  1.8
# ...             ...         ...  ...                ...                  ...
# 1604133     1604133  2020-04-18  ...                NaN                  NaN
# 1604134     1604134  2020-04-19  ...                NaN                  NaN
# 1604135     1604135  2020-04-20  ...                NaN                  1.0
# 1604136     1604136  2020-04-21  ...                NaN                  1.0
# 1604137     1604137  2020-04-22  ...                NaN                  NaN
#
# [3110 rows x 96 columns]

# %%
df_ticker = df.groupby(["Ticker"])

# %%
df_ticker.count()
# Out:
#         Unnamed: 0  Timestamp  ...  SDG_17_News_Volume  SDG_News_Volume_Mean
# Ticker                         ...
# A             2579       2579  ...                 363                  2058
# AAL           2579       2579  ...                2291                  2572
# AAP           2579       2579  ...                 201                  1829
# AAPL          2579       2579  ...                2278                  2573
# ABBV          2579       2579  ...                 762                  2251
# ...            ...        ...  ...                 ...                   ...
# Z             2579       2579  ...                 348                  1803
# ZAYO          2579       2579  ...                  85                  1148
# ZBH           2579       2579  ...                 123                  1466
# ZION          2579       2579  ...                2299                  2575
# ZTS           2579       2579  ...                 142                  1587
#
# [622 rows x 95 columns]

# %% [markdown]
# ## Data Proprocessing

# %% [markdown]
# removing columns we do not need,
# check missing values,

# %% [markdown]
# ## Indexing with Time Series Data
